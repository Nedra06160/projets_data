# %%
import pandas as pd

donnees = pd.read_csv("/home/simplon/netflix_titles.csv",index_col="show_id")

donnees
# Out:
#              type                                        title  \
# show_id
# 81145628    Movie      Norm of the North: King Sized Adventure
# 80117401    Movie                   Jandino: Whatever it Takes
# 70234439  TV Show                           Transformers Prime
# 80058654  TV Show             Transformers: Robots in Disguise
# 80125979    Movie                                 #realityhigh
# ...           ...                                          ...
# 80000063  TV Show                                 Red vs. Blue
# 70286564  TV Show                                        Maron
# 80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 70153404  TV Show                                      Friends
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# ...

# %%
2 #écrire le code pour afficher les dimensions du dataframe
donnees.shape
# Out:
# (6234, 11)

# %%
#écrire le code qui permet d’afficher le nombre de films et le nombre de séries stockés dansce jeu de données.
donnees.loc[donnees['type']=='Movie']
donnees['type'].value_counts()

#donnees.type.valucount()
# Out:
# Movie      4265
# TV Show    1969
# Name: type, dtype: int64

# %%
# générer le code pour afficher le résumé statistique du dataframe pour l’ensemble des va-riables
donnees.describe(include='all')
# Out:
#              show_id   type   title                director  \
# count   6.234000e+03   6234    6234                    4265
# unique           NaN      2    6172                    3301
# top              NaN  Movie  Tunnel  Raúl Campos, Jan Suter
# freq             NaN   4265       3                      18
# mean    7.670368e+07    NaN     NaN                     NaN
# std     1.094296e+07    NaN     NaN                     NaN
# min     2.477470e+05    NaN     NaN                     NaN
# 25%     8.003580e+07    NaN     NaN                     NaN
# 50%     8.016337e+07    NaN     NaN                     NaN
# 75%     8.024489e+07    NaN     NaN                     NaN
# max     8.123573e+07    NaN     NaN                     NaN
#
#                       cast        country       date_added  release_year  \
# count                 5664           5758             6223    6234.00000
# unique                5469            554             1524           NaN
# ...

# %%
# écrire le code pour afficher le nombre de valeurs manquantes par colonne du dataframe
donnees.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        1969
# cast             570
# country          476
# date_added        11
# release_year       0
# rating            10
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
#écrire le code pour sélectionner les lignes pour lesquelles la valeur est manquante dans lacolonne director,
#puis compter le nombre de films et de séries sans directeur de production
donnees2 = donnees.loc[donnees['director'].isna(),:]
donnees2
donnees2['type'].value_counts()
donnees3 = donnees.loc[donnees['cast'].isna(),:]
donnees3
# Out:
#        show_id     type                                             title  \
# 8     80117902  TV Show                                      Fire Chasers
# 22    80046727    Movie                                    Rolling Papers
# 27    80203094    Movie                                       City of Joy
# 28    80190843  TV Show                                    First and Last
# 66    81011682  TV Show  Christiane Amanpour: Sex & Love Around the World
# ...        ...      ...                                               ...
# 6205  80036747  TV Show                       Pororo - The Little Penguin
# 6207  80190407  TV Show                                 Murderous Affairs
# 6211  80231523  TV Show                               The Minimighty Kids
# 6214  80049872  TV Show                                           Chelsea
# 6231  80116008    Movie            Little Baby Bum: Nursery Rhyme Friends
#
#              director cast                 country          date_added  \
# ...

# %%
donnees3 = donnees2['listed_in'].value_counts()
donnees3.head(10)
# Out:
# Kids' TV                                                  155
# International TV Shows, TV Dramas                          87
# Crime TV Shows, International TV Shows, TV Dramas          84
# International TV Shows, Romantic TV Shows, TV Dramas       77
# Kids' TV, TV Comedies                                      68
# International TV Shows, Romantic TV Shows, TV Comedies     65
# Anime Series, International TV Shows                       57
# Docuseries                                                 53
# Reality TV                                                 51
# TV Comedies                                                51
# Name: listed_in, dtype: int64

# %%
7# écrire le code pour compter le nombre de lignes dupliquées 
#et pour les supprimer du data-frame.
donnees. duplicated()
donnees.drop_duplicates()
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
#8. Compter les films/séries produits par les États-Unis et par la France
data_film_usa = donnees.loc[donnees.country == 'United States', 'title'] 
data_film_fr = donnees.loc[donnees.country == 'France', 'title']
print(data_film_usa.shape[0])
# Out:
# 2032

# %%
#9. Afficher le contenu le plus vieux disponible sur Netflix
data_older = donnees.loc[donnees.release_year == donnees.release_year.min(), ['title', 'release_year']]
print(data_older)
# Out:
#                                   title  release_year
# 4292  Pioneers: First Women Filmmakers*          1925

# %%
#10. Afficher le film avec la durée la plus longue sur Netflix
#Afficher les 5 films les + long(juste la durée)
data_movies = donnees.loc[donnees.type == 'Movie']
duree = pd.Series(data_movies['duration']).str.replace(" min", "").astype('int').sort_values(ascending=False).head(5)
print(duree)
# Out:
# 4315    312
# 4227    228
# 4106    224
# 870     214
# 1100    209
# Name: duration, dtype: int64

# %%
#11. Affiche les 5 films avec toutes les infos
donnees["duration"] = pd.Series(data_movies['duration']).str.replace(" min", "").astype('int')
data_film_duration_2 = donnees.sort_values(by='duration', ascending=False).head(5)
data_film_duration_2
# Out:
#        show_id   type                       title            director  \
# 4315  80988062  Movie  Black Mirror: Bandersnatch                 NaN
# 4227  60002818  Movie                      Sangam          Raj Kapoor
# 4106  60020906  Movie                      Lagaan  Ashutosh Gowariker
# 870   70090035  Movie                Jodhaa Akbar  Ashutosh Gowariker
# 1100  80175798  Movie                The Irishman     Martin Scorsese
#
#                                                    cast        country  \
# 4315  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
# 4227  Raj Kapoor, Vyjayanthimala, Rajendra Kumar, La...          India
# 4106  Aamir Khan, Gracy Singh, Rachel Shelley, Paul ...          India
# 870   Hrithik Roshan, Aishwarya Rai Bachchan, Sonu S...          India
# 1100  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...  United States
#
#              date_added  release_year rating  duration  \
# 4315  December 28, 2018          2018  TV-MA     312.0
# ...

# %%
#12. Afficher les directeurs qui ont produit le plus de
#films/séries disponibles sur Netflix
directors = pd.Series(", ".join(donnees["director"].dropna()).split(", "))
directors
# Out:
# 0               Richard Finn
# 1                 Tim Maltby
# 2           Fernando Lebrija
# 3                Gabe Ibáñez
# 4               Rodrigo Toro
#                 ...
# 4847           Thomas Astruc
# 4848    Vikramaditya Motwane
# 4849          Anurag Kashyap
# 4850              Jung-ah Im
# 4851               Onur Ünlü
# Length: 4852, dtype: object

# %%
#13. Voir si Jan Suter travaille souvent avec les mêmes acteurs

directors_notna=donnees[donnees['director'].notna()]
donnees_jan_suter=directors_notna[directors_notna['director'].str.contains("Jan Suter")]
donnees_jan_suter
jan_suter_cast=pd.Series(', '.join(donnees_jan_suter['cast'].dropna()).split(', '))
jan_suter_cast.value_counts().head(5)
# Out:
# Carlos Ballarta         3
# Sofía Niño de Rivera    3
# Ricardo O'Farrill       2
# Antonio Sanint          1
# Lucas Lauriente         1
# dtype: int64

# %%
#14. Représenter les dix pays qui ont produit le plus de contenus disponibles sur Netflix, 
#avec le nombre de contenus par pays

donnees_pays=pd.Series(", ".join(donnees['country'].dropna()).split(", "))
donnees_pays=donnees_pays.value_counts().head(10)
donnees_pays

#suite 14

#donnees.loc[donnees['country'].isin(donnees_pays.index)]

dataframe_pays=donnees[donnees["country"].isin(donnees_pays.index)]
dataframe_pays
# Out:
#              type                                        title  \
# show_id
# 80117401    Movie                   Jandino: Whatever it Takes
# 70234439  TV Show                           Transformers Prime
# 80058654  TV Show             Transformers: Robots in Disguise
# 80125979    Movie                                 #realityhigh
# 80163890  TV Show                                      Apaches
# ...           ...                                          ...
# 70243132  TV Show                          La Familia P. Luche
# 80000063  TV Show                                 Red vs. Blue
# 70286564  TV Show                                        Maron
# 70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 70153404  TV Show                                      Friends
#
#                   director                                               cast  \
# show_id
# 80117401               NaN                                   Jandino Asporaat
# ...

# %%
#15 Tracer un countplot grâce à la fonction countplot() de Seaborn 
#en lui donnant le nouveau data-frame et la variable souhaitée : country.
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=[15,10])
sns.countplot(x="country", data=dataframe_pays,order =dataframe_pays ["country"].value_counts().keys())
plt.xticks(rotation=90)
plt.show()

# %%
#15. Tracer un graphe à barres du nombre de films/séries parclassement de contenu (rating)

plt.figure(figsize=[15,10])
sns.countplot(x="rating", data=donnees,
    order = donnees["rating"].value_counts().keys())
plt.xticks(rotation=90)
plt.title("nombre de films/séries par classement de contenu (rating)")
plt.ylabel("nombre de films/séries")
plt.xlabel("Notation")
plt.show()

# %%
#16. Afficher l’évolution du nombre de films/séries disponibles sur Netflix au cours du temps
#1st_part
data=donnees[donnees['date_added'].notna()]
date_year= pd.to_datetime(data['date_added']).dt.year
date_year
# Out:
# show_id
# 81145628    2019
# 80117401    2016
# 70234439    2018
# 80058654    2018
# 80125979    2017
#             ...
# 80162994    2019
# 80186475    2019
# 70272742    2016
# 80067942    2016
# 70136122    2014
# Name: date_added, Length: 6223, dtype: int64

# %%
#2ndpart
donnees['year_added']=date_year
donnees
# Out:
#              type                                        title  \
# show_id
# 81145628    Movie      Norm of the North: King Sized Adventure
# 80117401    Movie                   Jandino: Whatever it Takes
# 70234439  TV Show                           Transformers Prime
# 80058654  TV Show             Transformers: Robots in Disguise
# 80125979    Movie                                 #realityhigh
# ...           ...                                          ...
# 80000063  TV Show                                 Red vs. Blue
# 70286564  TV Show                                        Maron
# 80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 70153404  TV Show                                      Friends
#
#                           director  \
# show_id
# 81145628  Richard Finn, Tim Maltby
# 80117401                       NaN
# 70234439                       NaN
# 80058654                       NaN
# ...

# %%
#3rdpart
data_group=donnees.groupby(['type','year_added']).size().reset_index(name='Count')
data_group
# Out:
#        type  year_added  Count
# 0     Movie      2008.0      1
# 1     Movie      2009.0      2
# 2     Movie      2010.0      1
# 3     Movie      2011.0     13
# 4     Movie      2012.0      4
# 5     Movie      2013.0      6
# 6     Movie      2014.0     19
# 7     Movie      2015.0     58
# 8     Movie      2016.0    264
# 9     Movie      2017.0    913
# 10    Movie      2018.0   1290
# 11    Movie      2019.0   1546
# 12    Movie      2020.0    147
# 13  TV Show      2008.0      1
# 14  TV Show      2012.0      3
# 15  TV Show      2013.0      6
# 16  TV Show      2014.0      6
# 17  TV Show      2015.0     32
# 18  TV Show      2016.0    192
# 19  TV Show      2017.0    387
# 20  TV Show      2018.0    492
# 21  TV Show      2019.0    803
# 22  TV Show      2020.0     37

# %%
#4thpart
plt.figure(figsize=[15,5])
plt.xticks(rotation=90)
sns.pointplot('year_added', 'Count', hue = 'type', data=data_group)

# %%
#17. Afficher la distribution de la durée des films disponibles sur Netflix
movie = donnees[(donnees["type"]=="Movie")]
#duree = pd.Series(movie['duration']).str.replace("min", "").astype("int").sort_values(ascending=False)
duree = pd.Series(movie['duration']).str.replace(" min", "").astype('int').sort_values(ascending=False)
sns.distplot(duree)

# %%
#18. Tracer un graphique représentant le nombre de séries par modalité de nombre de saisonsAction :
#créer un dataframe des contenus de type TV Show uniquement 
#puis tracer un countplot()pour représenter le nombre de séries pour chaque modalité du nombre de saisons.
#Indices :Utiliser la sélection booléenne pour créer le dataframe des séries.La variable utile en x est la variable duration,
#contenant l’information du nombre de saisonspour chaque série
donnees_series=donnees.loc[donnees['type']=='TV Show'] 
donnees_series
sns.countplot(x='duration', data=donnees_series)
plt.xticks(rotation=90)
plt.figure(figsize=[30,20])
